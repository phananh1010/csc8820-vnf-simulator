64008 bytes from 131.96.131.250: icmp_seq=35 ttl=64 time=4.27 ms
64008 bytes from 131.96.131.250: icmp_seq=36 ttl=64 time=3.94 ms
64008 bytes from 131.96.131.250: icmp_seq=37 ttl=64 time=4.26 ms
64008 bytes from 131.96.131.250: icmp_seq=38 ttl=64 time=4.22 ms
64008 bytes from 131.96.131.250: icmp_seq=39 ttl=64 time=3.72 ms
64008 bytes from 131.96.131.250: icmp_seq=40 ttl=64 time=3.87 ms
64008 bytes from 131.96.131.250: icmp_seq=41 ttl=64 time=4.69 ms
64008 bytes from 131.96.131.250: icmp_seq=42 ttl=64 time=3.83 ms
64008 bytes from 131.96.131.250: icmp_seq=43 ttl=64 time=4.34 ms
64008 bytes from 131.96.131.250: icmp_seq=44 ttl=64 time=4.37 ms
64008 bytes from 131.96.131.250: icmp_seq=45 ttl=64 time=4.43 ms
64008 bytes from 131.96.131.250: icmp_seq=46 ttl=64 time=3.96 ms
64008 bytes from 131.96.131.250: icmp_seq=47 ttl=64 time=4.50 ms
64008 bytes from 131.96.131.250: icmp_seq=48 ttl=64 time=4.10 ms
64008 bytes from 131.96.131.250: icmp_seq=49 ttl=64 time=4.22 ms'''

# %%
#our algorithm min-max performance, with my own calculation
minmax_delay_1k  = [0.7230697002279787, 0.7610441898469599, 1.1391970887118228, 0.763063045693936, 0.7463981849936983, 1.0014962081414558, 0.8049542162275872, 0.958106803760266, 0.8454554134325758]
minmax_delay_64k = [3.7989444243890835, 3.7122971970385814, 7.048538952081029, 4.01855109962456, 4.2115578130859745, 5.5755504432982725, 3.3772213896637537, 6.6551342230880675, 3.0744352412870217]
minmax_delay_1k = np.array(minmax_delay_1k)
minmax_delay_64k = np.array(minmax_delay_64k)

maxmin_delay_1k  = [0.869079932242852, 0.7530658836844065, 1.100543434219282, 0.7503024406346467, 0.7392578880972456, 1.0638971732303253, 0.8069041566538755, 1.102086789410608, 0.7366013960613824]
maxmin_delay_64k = [4.049425136219756, 3.661715084701064, 6.04782587357691, 3.431288634815455, 4.13830771253855, 6.565650395327328, 4.08928934963466, 5.944044194147804, 3.8533424393429243]
maxmin_delay_1k = np.array(maxmin_delay_1k)
maxmin_delay_64k = np.array(maxmin_delay_64k)





minmax_packet_1k = np.array([0, 0, 8000, 0, 0, 8000, 0, 8000, 0])
minmax_packet_64k = np.array([0, 0, 512000, 0, 0, 512000, 0, 512000, 0])
maxmin_packet_1k = np.array([0, 0, 8000, 0, 0, 8000, 0, 8000, 0])
maxmin_packet_64k = np.array([0, 0, 512000, 0, 0, 512000, 0, 512000, 0])

# %%
#result from mart
minmax_delay_1k = [0.7598337021467061, 0.7281836973239226, 1.2059700628945111, 0.9670034295089538, 1.0795793608380464, 1.0494282986989023, 0.7768287019392244, 1.0687962143184735, 0.8449431145393946]
minmax_delay_64k = [4.05864861661766, 3.7604655981965633, 6.835014166834258, 7.649658184235798, 7.586699280152838, 6.019100948593488, 3.6309122791975588, 6.615011458987134, 3.694103552043307]

# %%
import numpy as np
from matplotlib import pyplot as plt
def parse_timelist(mtext):
    tmp = mtext.replace('time=', '').replace(' ms', '').split('\n')[1:-1]
    time_list = [float(item.split(' ')[-1]) for item in tmp]
    return np.array(time_list)

# %%
time_list1 = parse_timelist(text_intra_ping)
time_list2 = parse_timelist(text_inter_ping)
time_list3 = parse_timelist(text_intra_delay_64)
time_list4 = parse_timelist(text_inter_delay_64)
print time_list1.mean(), time_list1.std()
print time_list2.mean(), time_list2.std()
print time_list3.mean(), time_list3.std()
print time_list4.mean(), time_list4.std()

gath_packet_1k = 1000*2*8
dist_packet_1k = 1000*2*8 + 3*1000*8

gath_packet_64k = 64000*2*8
dist_packet_64k = 64000*2*8 + 3*64000*8
# Out:
# 0.25599999999999995 0.02926162032838278
# 0.5936666666666667 0.09116622013381158
# 1.2698529411764705 0.18441076789298097
# 4.144255319148937 0.5017744881316624

# %%
y = np.array([time_list1.mean(), (minmax_delay_1k.mean())/3., (maxmin_delay_1k.mean())/3., time_list2.mean()])
y = y*3
x = range(len(y))
object_list = ['G','GLSA', 'GLSB', 'D']
plt.bar(x, y, align='center', alpha=0.5)
plt.xticks(x, object_list, fontsize=16)
plt.xlabel('', fontsize=16)
#plt.title('Delay for different placement strategies. Packetsize = 1000 Bytes')
plt.ylabel('ms', fontsize=16)
plt.figure()

y = np.array([time_list3.mean(), (minmax_delay_64k.mean())/3., (maxmin_delay_64k.mean())/3., time_list4.mean()])
y = y*3
x = range(len(y))
object_list = ['G','GLSA', 'GLSB', 'D']
plt.bar(x, y, align='center', alpha=0.5)
plt.xticks(x, object_list, fontsize=16)
plt.xlabel('')
plt.ylabel('ms', fontsize=16)
#plt.title('Delay for different placement strategies. Packetsize = 64000 Bytes')
# Out:
# Text(0,0.5,'ms')

# %%
y = np.array([gath_packet_1k, gath_packet_1k + minmax_packet_1k.mean(), gath_packet_1k + minmax_packet_1k.mean(), dist_packet_1k])
y=y/1000000.
x = range(len(y))
object_list = ['G','GLSA', 'GLSB', 'D']
plt.bar(x, y, align='center', alpha=0.5)
plt.xticks(x, object_list, fontsize=16)
plt.xlabel('', fontsize=16)
#plt.title('Delay for different placement strategies. Packetsize = 1000 Bytes')
plt.ylabel('Mbps', fontsize=16)
plt.figure()

y = np.array([gath_packet_64k, gath_packet_64k + minmax_packet_64k.mean(), gath_packet_64k + minmax_packet_64k.mean(), dist_packet_64k])
y=y/1000000.
x = range(len(y))

object_list = ['G','GLSA', 'GLSB', 'D']
plt.bar(x, y, align='center', alpha=0.5)
plt.xticks(x, object_list, fontsize=16)
plt.xlabel('')
plt.ylabel('Mbps', fontsize=16)
#plt.title('Delay for different placement strategies. Packetsize = 64000 Bytes')
# Out:
# Text(0,0.5,'Mbps')
